# %% [markdown]
# # ADABOOST
# ## Изучите код

# %%
# Загрузка необходимых библиотек
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn import metrics
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
def plotIrisData(iris):
    # функция построения графика
    x_index = 0
    
    y_index = 1

    plt.figure(figsize=(5, 4))
    plt.scatter(iris.data[:, x_index], iris.data[:, y_index], c=iris.target)
    plt.xlabel(iris.feature_names[x_index])
    plt.ylabel(iris.feature_names[y_index])

    plt.tight_layout()
    plt.show()

# %%
# Iris — небольшой набор данных для задачи классификации, опубликованный еще в 1936 году Робертом Фишером,
# используя данные биолога Эдгара Андерсона. В этом наборе данных представлены по 50 описаний цветков
# одного из трех типов — Ирис щетинистый (Iris setosa), Ирис виргинский (Iris virginica) и Ирис разноцветный (Iris versicolor).
# Для каждого цветка измерены четыре величины — длина чашелистника (англ. sepal length), ширина чашелистника (sepal width),
# длина лепестка (англ. petal length), ширина лепестка (англ. petal width). Все цветки промаркированы одним из трех типов,
# что позволяет тестировать на нем алгоритмы классификации.

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
# Посмотрим на данные
data1 = pd.DataFrame(data= np.c_[iris['data'], iris['target']], 
                     columns= iris['feature_names'] + ['target']) #np.c_ это функция конкатенации
data1.head()

# %%
data1.info()

# %% [markdown]
# Как видим, датасет достаточно небольшой, всего 150 объектов без пропусков в данных.

# %%
plotIrisData(iris) # интересно заметить, что один из видов ирисов мы можем отделить от остальных графиков линейной функции.

# %%
# Разделим наши данные на тестовые и тренировочные
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Описание параметров функции AdaBoost
#
# 1. n_estimators (int) - количество прогонов обучения, количество циклов обучения, количество созданных последовательно моделей. По умолчанию 50.
# 2. learning_rate (float) - скорость обучения. Этот параметр ограничевает глубину каждого дерева. По умолчанию 1.

# %%
# Создаем классификатор
abc = AdaBoostClassifier(n_estimators=600,
                         learning_rate=10)
# Обучаем его
model = abc.fit(X_train, y_train)

# Получаем предсказания
y_pred = model.predict(X_test)

print(y_pred)

# %%
# Смотрим точность
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# ### Задание 1
# Напишите функцию обучения, которая на вход принимает все данные, процент деления данных на выборку для обучения и для тестов, два параметра обучения. Функция возвращает точность обучения.

# %%
def training_function(x,y,size_of_test_dataset, n, learn_rate):
    # ваш код
     return 'точность обучения'

# %%
#N_estimators=int(input('time: '))
#Learning_rate=float(input('depth: '))
#test_percent=int(input('percent: '))/100
#herald(N_estimators,Learning_rate,test_percent)

while True:
    learning_rate=float(input('depth: '))
    if learning_rate==0.0:
        break
    else:
        training_function(X, y, 0.2, 100, learning_rate)

# %%
data=[]
for n in range(1, 51):
    data.append([n, training_function(X, y, 0.2, n, 1)])
plt.plot([data[x][0] for x in range(len(data))], [data[x][1] for x in range(len(data))], c='#ffff00')
plt.tight_layout()
plt.show()
